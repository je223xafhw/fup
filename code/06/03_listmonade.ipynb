-- %% [markdown]
-- ## 3
-- ```haskell
--     (xs >>= f) >>= g   == xs >>= (\x -> f x) >>= g
-- case xs of
--     [] -> ([] >>= f) >>= g
-- =   [] >>= g
-- =   []
-- =   [] >>= \x -> (f >>= g)
--
--     (x:xs) >>= f >>= g
--     f = (\x -> f x)
--     g = (\y -> g y)
--     -- linke seite
--     xs >>= `(f x ++ (xs >>= f))` >>= g
--     -- rechte seite
--     xs >>= (\x -> f x) >>= g
--     xs >>= \x -> `f x ++ (xs >>= f)` >>= g
--
--     für alle xs annehmen dass (xs >>= f) = xs >>= (\x -> f x >>= g)

-- %%
main = do
    x <- [2,3]
    return x

main
-- Out:
-- Line 1: Redundant return
-- Found:
-- do x <- [2, 3]
--    return x
-- Why not:
-- do [2, 3]
-- [2,3]

-- %% [markdown]
-- ```haskell
--
-- (xs `mplus` ys) >>= return = (xs >>= return) `mplus` (ys >>= return)
--
-- (a + b) * c = a c + b c
--
-- -- linke seite
--     (xs `mplus` ys) >>= return
--                xsys >>= return == xsys
-- ==  (xs `mplus` ys)
--
--
-- -- rechte seite
--     (xs >>= return) `mplus` (ys >>= return)
-- ==  (xs `mplus` ys) == xs ++ ys == xsys

-- %%
listasdo :: Monad m => m [a] -> ([a] -> Bool) -> m [a]
listasdo xs g = do
    x <- xs
    if g x then
        return (x)
    else 
        return []

listasdo [1,2] (\x -> x `mod` 2 == 0)
-- Out:
-- Line 5: Redundant bracket
-- Found:
-- (x)
-- Why not:
-- xLine 9: Use even
-- Found:
-- x `mod` 2 == 0
-- Why not:
-- even x
-- <interactive>:1:1: error:
--     • No instance for (Integral [()]) arising from a use of ‘it’
--     • In the first argument of ‘print’, namely ‘it’
--       In a stmt of an interactive GHCi command: print it

-- %% [markdown]
-- ```haskell
-- [ Ausdruck | var1 <- Liste1, var2 <- Liste2, ..., Bedingungen ]
--
--
-- do
--   var1 <- Liste1
--   var2 <- Liste2
--   ...
--   if Bedingungen then
--     return Ausdruck
-- else
--   return ()
